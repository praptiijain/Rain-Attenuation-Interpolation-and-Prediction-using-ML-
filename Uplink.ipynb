# %%
import math
pt=20 #transmitted power
n=0.55 #antenna efficiency 
f=5
D=3 #antenna diameter
r=10000 #distance
Gt=n(3.192fD)^2 #gain of transmitting antenna
Gtd=10*(math.log(Gt,10)) #gain of tramitting antenna in dB
eirp=pt+Gtd
fsl=32.4+(20*(math.log(r,10)))+(20*(math.log(f,10))) #free space loss
aml=                                                 #atenna misalignment loss
Fcloss=fsl+aml+rfl+aa+pl   #total constant losses
pr=pt+Gr-Fcloss #received power
# Out:
# 200
