# %% [markdown]
# Getting Latitude and Longitude for any mentioned location
# #ITU-R P.837

# %%
from geopy.geocoders import Nominatim


geolocator = Nominatim(user_agent="MyApp")
city1='Delhi'

location = geolocator.geocode(city1)
Lat=location.latitude
Lon=location.longitude

print("Lat:", Lat)
print("Lon: ", Lon)
# Out:
# Lat: 28.6517178
# Lon:  77.2219388

# %%
Aiallcities=[]
city=1
for city in range(1,5):
  if city==1:
    T=[287.153563, 290.519574, 295.963952,302.354184, 306.048907, 306.507869, 303.636607, 302.656573, 301.789416, 298.546718, 293.158063, 288.463691 ]  #Tii values for sample, to be taken from local data                    #TBE
    MT=[17.627556, 14.730875, 10.138234,6.914227, 8.625949, 36.161384, 188.164508, 183.523770, 109.466133, 18.547533, 2.657261, 3.967131] #MTii values for sample, to be taken from local data                               #TBE
    h0=4.9123#using BLI in matlab
    hs=0.225    ######calculated using BLI as stated in ITU-R P.1511 #require TOPO0DOT5 file
    R001=61.8779 #R0.01 value 
    city=city+1


  elif city==2:
    T=[287.153563, 290.519574, 295.963952,302.354184, 306.048907, 306.507869, 303.636607, 302.656573, 301.789416, 298.546718, 293.158063, 288.463691 ]  #Tii values for sample, to be taken from local data                    #TBE
    MT=[17.627556, 14.730875, 10.138234,6.914227, 8.625949, 36.161384, 188.164508, 183.523770, 109.466133, 18.547533, 2.657261, 3.967131] #MTii values for sample, to be taken from local data                               #TBE
    h0=4.9123#using BLI in matlab
    hs=0.225    ######calculated using BLI as stated in ITU-R P.1511 #require TOPO0DOT5 file
    R001=61.8779 #R0.01 value 
    city=city+1

  elif city==3:
    T=[287.153563, 290.519574, 295.963952,302.354184, 306.048907, 306.507869, 303.636607, 302.656573, 301.789416, 298.546718, 293.158063, 288.463691 ]  #Tii values for sample, to be taken from local data                    #TBE
    MT=[17.627556, 14.730875, 10.138234,6.914227, 8.625949, 36.161384, 188.164508, 183.523770, 109.466133, 18.547533, 2.657261, 3.967131] #MTii values for sample, to be taken from local data                               #TBE
    h0=4.9123#using BLI in matlab
    hs=0.225    ######calculated using BLI as stated in ITU-R P.1511 #require TOPO0DOT5 file
    R001=61.8779 #R0.01 value 
    city=city+1

  elif city==4:
    T=[287.153563, 290.519574, 295.963952,302.354184, 306.048907, 306.507869, 303.636607, 302.656573, 301.789416, 298.546718, 293.158063, 288.463691 ]  #Tii values for sample, to be taken from local data                    #TBE
    MT=[17.627556, 14.730875, 10.138234,6.914227, 8.625949, 36.161384, 188.164508, 183.523770, 109.466133, 18.547533, 2.657261, 3.967131] #MTii values for sample, to be taken from local data                               #TBE
    h0=4.9123#using BLI in matlab
    hs=0.225    ######calculated using BLI as stated in ITU-R P.1511 #require TOPO0DOT5 file
    R001=61.8779 #R0.01 value 
    city=city+1

  else:
    print('error')
  print('success')
# Out:
# success
# success
# success
# success

# %% [markdown]
# Calculation Prain by estimation as p annual
# #ITU-R P.1853
# #Step A1

# %%
Aiallcitieslist=[]
mulist=[]
sigmalist=[]
Pannuallist=[]
thetaall=[]
thetadall=[]
Piallcitieslist=[]
MTall=[]
lnAiall=[]
QAall=[]
Qall=[]
Yrainall=[]
Arainall=[]


for city in range(1,5):
  if city==1:
    #print('City1')
    T=[287.153563, 295.519574, 298.963952,308.354184, 339.048907, 352.507869, 321.636607, 322.656573, 301.789416, 298.546718, 293.158063, 288.463691 ]  #Tii values for sample, to be taken from local data                    #TBE
    MT=[19.627556, 19.730875, 17.138234,9.914227, 115.625949, 146.161384, 298.164508, 283.523770, 109.466133, 18.547533, 2.657261, 3.967131] #MTii values for sample, to be taken from local data                               #TBE
    MTall.append(MT)
    h0=8.9123#using BLI in matlab
    hs=2.625    ######calculated using BLI as stated in ITU-R P.1511 #require TOPO0DOT5 file
    R001=75.8779 #R0.01 value
    Lat=35.55
    Lon=88
    #city=city+1 

  elif city==2:
    #print('City2')
    T=[287.153563, 295.519574, 295.963952,302.354184, 316.048907, 316.507869, 313.636607, 312.656573, 301.789416, 298.546718, 293.158063, 288.463691 ]  #Tii values for sample, to be taken from local data                    #TBE
    MT=[17.627556, 14.730875, 10.138234,6.914227, 18.625949, 36.161384, 288.164508, 393.523770, 119.466133, 19.547533, 2.657261, 3.967131] #MTii values for sample, to be taken from local data                               #TBE
    MTall.append(MT)
    h0=5.9123#using BLI in matlab
    hs=0.325    ######calculated using BLI as stated in ITU-R P.1511 #require TOPO0DOT5 file
    R001=65.8779 #R0.01 value
    Lat=34
    Lon=67
    #city=city+1 

  elif city==3:
    #print('City3')
    T=[287.153563, 295.519574, 295.963952,302.354184, 336.048907, 316.507869, 303.636607, 322.656573, 301.789416, 298.546718, 298.158063, 288.463691 ]  #Tii values for sample, to be taken from local data                    #TBE
    MT=[17.627556, 14.730875, 10.138234,6.914227, 18.625949, 36.161384, 188.164508, 283.523770, 119.466133, 18.547533, 8.657261, 6.967131] #MTii values for sample, to be taken from local data                               #TBE
    MTall.append(MT)
    h0=3.9123#using BLI in matlab
    hs=0.125    ######calculated using BLI as stated in ITU-R P.1511 #require TOPO0DOT5 file
    R001=54.8779 #R0.01 value 
    Lat=23
    Lon=92
    #city=city+1

  elif city==4:
    #print('City4')
    T=[287.153563, 290.519574, 295.963952,302.354184, 306.048907, 306.507869, 303.636607, 302.656573, 301.789416, 298.546718, 293.158063, 288.463691 ]  #Tii values for sample, to be taken from local data                    #TBE
    MT=[17.627556, 14.730875, 10.138234,6.914227, 8.625949, 36.161384, 188.164508, 183.523770, 109.466133, 18.547533, 2.657261, 3.967131] #MTii values for sample, to be taken from local data                               #TBE
    MTall.append(MT)
    h0=4.9123#using BLI in matlab
    hs=0.225    ######calculated using BLI as stated in ITU-R P.1511 #require TOPO0DOT5 file
    R001=61.8779 #R0.01 value
    Lat=28.65
    Lon=77.20
    #city=city+1 

  else:
    print('error')
  #print('Cities')





#ITU-R P.837
#Calculating P0 annual


  import numpy as np
  import math


  month=[[1,31],[2,28.25],[3,31],[4,30],[5,31],[6,30],[7,31],[8,31],[9,30],[10,31],[11,30],[12,31]] #list in format[ii,Ni]
  Months=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
  N=[31,28.25,31,30,31,30,31,31,30,31,30,31]
#T=[287.153563, 290.519574, 295.963952,302.354184, 306.048907, 306.507869, 303.636607, 302.656573, 301.789416, 298.546718, 293.158063, 288.463691 ]  #Tii values for sample, to be taken from local data                    #TBE
#MT=[17.627556, 14.730875, 10.138234,6.914227, 8.625949, 36.161384, 188.164508, 183.523770, 109.466133, 18.547533, 2.657261, 3.967131] #MTii values for sample, to be taken from local data                               #TBE
  R=[]
  P=[]


  f=15 #GHz
  phid=Lat     #latitude of the earth station (degrees) 
  phi=math.radians(phid) 
  LonS=74 ###TBE satellite position in degrees    (74 degree) 
  towd=45
  tow=math.radians(towd)


#Step 4
  for i in range(0,12):
    T[i]=T[i]-273.15 #Tii list converted from k to C

#calculating rii values (Step5)
  for j in T:     #j is tii in the formula
    if j>=0:
      r=0.5874*np.exp(0.0883*j)
      R.append(r)
    elif j<0:
      r=0.5874
      R.append(r) #rii values list

#calculating Pii values (Step6A)
  for k in range(0,12):
    p=100*MT[k]/(24*N[k]*R[k]) 
    P.append(p) #adding Pii values in list of p

#Step 6B
  for l in range(0,12):
    if P[l]>70:
      P[l]=70
      R[l]=5*MT[l]/(84*N[l])

#Step 7 Calculating P annual
  sum=0
  for m in range(0,12):
    x=P[m]*N[m] #x denotes the product of Nii and P0ii
    sum=sum+x
  Pannual=sum/365.25
  Pannuallist.append(Pannual)
  #print('Pannual:',Pannual)





###############################################################################
###    Average monthly rainfall plot ##########3
###############################################################################




  



###############################################################################
###    STEPA1 ##########3
###############################################################################
## ITU-R P.838

  import math

  delta=(math.radians(LonS))-(math.radians(Lon))         
  numcos=(math.cos(delta))*(math.cos(phi))
#theta=10 #elevation angle theta i degrees
#theta = math.atan((cosphi-(Re/(Re+RO)))/math.sqrt(1-(cosphi)**2))*(180/math.pi)
  theta=math.atan((numcos-0.1512)/math.sqrt(1-numcos**2))
  thetad=math.degrees(theta)
  thetaall.append(theta)
  thetadall.append(thetad)
  #print('theta elevation angle in degrees',thetad)



####ITU-R P.838

#aj,bj,cj, ck and mk values for kH
  akh=[-5.33980,-0.35351,-0.23789,-0.94158]
  bkh=[-0.10008,1.26970,0.86036,0.64552]
  ckh=[1.13098,0.45400,0.15354,0.16817]
  mkh=-0.18961
  cnstckh=0.71147

#kH calculation
  sumkh=0
  for i in range(0,4):
    sumtempkh=0
    powertempkh=-(((math.log(f,10)-bkh[i])/ckh[i])**2)
    sumtempkh=akh[i]*math.exp(powertempkh)
    sumkh=sumkh+sumtempkh

  logkh=sumkh+(mkh*math.log(f,10))+cnstckh
  kh=math.pow(10,logkh)
  #print('kh',kh)

###################

#aj,bj,cj, ck and mk values for kV
  akv=[-3.80595,-3.44965,-0.39902,0.50167]
  bkv=[0.56934,-0.22911,0.73042,1.07319]
  ckv=[0.81061,0.51059,0.11899,0.27195]
  mkv=-0.16398
  cnstckv=0.63297

#kV calculation
  sumkv=0
  for i in range(0,4):
    sumtempkv=0
    powertempkv=-(((math.log(f,10)-bkv[i])/ckv[i])**2)
    sumtempkv=akv[i]*math.exp(powertempkv)
    sumkv=sumkv+sumtempkv

  logkv=sumkv+(mkv*math.log(f,10))+cnstckv
  kv=math.pow(10,logkv)
  #print('kv',kv)

########################

#aj,bj,cj, c alpha and m alpha values for alpha H
  aah=[-0.14318,0.29591,0.32177,-5.37610,16.1721]
  bah=[1.82442,0.77564,0.63773,-0.96230,-3.29980]
  cah=[-0.55187,0.19822,0.13164,1.47828,3.43990]
  mah=0.67849
  cnstcah=-1.95537

#alpha H calculation
  sumah=0
  sumtempah=0
  for j in range(0,5):
  #sumtempah=0
    powertempah=-(((math.log(f,10)-bah[j])/cah[j])**2)
    sumtempah=aah[j]*math.exp(powertempah)
    sumah=sumah+sumtempah

  ah=sumah+(mah*math.log(f,10))+cnstcah
  #print('ah',ah)


########################


#aj,bj,cj, c alpha and m alpha values for alpha V
  aav=[-0.07771,0.56727,-0.20238,-48.2991,48.5833]
  bav=[2.33840,0.95545,1.14520,0.791669,0.791459]
  cav=[-0.76284,0.54039,0.26809,0.116226,0.116479]
  mav=-0.053739
  cnstcav=0.83433


#alpha V calculation
  sumav=0
  sumtempav=0
  for j in range(0,5):
  #sumtempav=0
    powertempav=-1*(((math.log(f,10)-bav[j])/cav[j])**2)
    sumtempav=aav[j]*math.exp(powertempav)
    sumav=sumav+sumtempav

  av=sumav+(mav*math.log(f,10))+cnstcav
  #print('av',av)

#################


#k and alpha values final caluclation

  c1=math.cos(theta)**2
  c2=math.cos(2*tow)

  k=(kh+kv+((kh-kv)*c1*c2))/2
  alpha=((kh*ah)+(kv*av)+(((kh*ah)-(kv*av))*c1*c2))/(2*k)
  #print('k:',k)
  #print('alpha:',alpha)

################################################################################
###############################################################################
###    STEPA2 ##########
###############################################################################
## ITU-R P.618


#import math

#all constants used

#h0=4.9123#using BLI in matlab
  hr=h0+0.36         #######ITU-R P.839
#hs=0.225    ######calculated using BLI as stated in ITU-R P.1511 #require TOPO0DOT5 file
  rs=hr-hs
  Re=8500                       #radius of earth in km
  RO=35786 #km
#R001=61.8779 #R0.01 value                                  

#ITU-R P.618
#Calculating Ai and Pi pairs



##Pi values

  PiList=[0.01,0.02,0.03,0.05,0.1,0.2,0.3,0.5,1]
  AiList=[]
  PiList = [ elem for elem in PiList if elem<=Pannual]
  Piallcitieslist.append(PiList)
  #print('Pi List:',PiList)

  Plen=len(PiList)
  for i in range(0,Plen):
    Pi=PiList[i]
###Ai values calculation for different Pi
#For Pi=0.01%

    if Pi==0.01:
      if rs<=0:
        A=0
  #Step 2
      else:
        if thetad>=5:
          Ls=(rs)/math.sin(theta)
        elif thetad<5:
          Ls=2*rs/(math.sqrt((math.sin(theta)**2)+(2*rs/Re))+math.sin(theta))

        if Ls<0:
          Ls=0
        else:
          Ls=Ls
    #Step 3
        Lg=Ls*math.cos(theta)

  #Step 4

      if R001==0:
        A=0
  #Step 5:

      else:
        yr=k*pow(R001,alpha) #gamma     
        #print('gamma:',yr)                                    
  #Step 6
      r=1/(1+(0.78*(math.sqrt(Lg*yr/f)))-(0.38*(1-(math.exp(-2*Lg)))))  #horizontal reduction factor

  #Step 7:
      zeta=math.degrees(math.atan(rs/(Lg*r)))
  ##Lr calculation
      if zeta>thetad:
        Lr=(Lg*r)/math.cos(theta)
      else:
        Lr=rs/math.sin(theta)

##Chi calculation
      if abs(phid)<36:
        chi=36-abs(phid)
      else:
        chi=0

##v 0.01 calculation 
      v=1/(1+((math.sqrt(math.sin(theta)))*((31*(1-(math.exp(-1*(thetad/(1+chi)))))*((math.sqrt(Lr*yr))/(f*f)))-0.45))) 

##Le calculation
      Le=Lr*v

###Attenuation calculation A0.01
      A=yr*Le                                         #Ai in dB
      AiList.append(A)

###For other values of Pi
    else:
  ### Beta values calculation
      if Pi>=1 or abs(phid)>=36:
        betaf=0
      elif Pi<1 and abs(phid)<36 and thetad>=25:
        betaf=-0.005*(abs(phid)-36)
      else:
        betaf=-0.005*(abs(phid)-36)+1.8-(4.25*math.sin(theta))
  
      Ap=A*pow((Pi/0.01),-(0.655+(0.033*math.log(Pi))-(0.045*math.log(A))-(betaf*(1-Pi)*math.sin(theta))))   #Ai in dB
   
      AiList.append(Ap)
  Aiallcitieslist.append(AiList)
  #print('Ai all cities List:',Ailist)



###List of Pi Ai pairs #nested list
  PiAiList=[]
  for i in range(0,Plen):
    templist=[]
    templist.append(PiList[i])
    templist.append(AiList[i])    #All Ai values in dB
    PiAiList.append(templist)

  #print('Pi and Ai pairs list',PiAiList)

  #print('\n')

  #######################################################################################################
  #######################################################################################################

#Q for converting Pi to Q(Pi)
  import numpy as np
  from scipy.integrate import quad
  import sympy as sy
  from scipy.stats import norm
  import scipy
  Qlist=[]
  for i in PiList:
    Qtemp=scipy.special.erfcinv(2*i)*math.sqrt(2) 
    Qlist.append(Qtemp)
  Qall.append(Qlist)
  #print('Qlist',Qlist)


  #print('\n')
  #######################################################################################################
  #######################################################################################################
  
  #ln Ai list
  lnAiList=[]
  for i in AiList:
    Atemp=i
    lnAtemp=math.log(Atemp) 
    lnAiList.append(lnAtemp)
  lnAiall.append(lnAiList)
  
  #print('ln Ai list',lnAiList)


#######################################################################################################
#######################################################################################################
  
 ######## STEP A3 ##########
  QAlist=[]
  for i in range(0,Plen):
    temp=[]
    temp.append(Qlist[i])
    temp.append(lnAiList[i])
    QAlist.append(temp)
  QAall.append(QAlist)
  #print('QA List',QAlist)

  #print('\n')
#######################################################################################################
#######################################################################################################







  #print('\n')
#######################################################################################################
#######################################################################################################
  
 ######## STEP  ##########
 ############ Arain vs percent of time exceeded ######################
  #import matplotlib.pyplot as plt
  #from pandas import Series
  #xPi=Series(PiList)
  #yAi=Series(AiList)
  #plt.xlabel('Pi')
  #plt.ylabel('Ai in dB')
  #plt.title('Attenuation vs percent time exceeded as per 618-8')
  #plt.plot(xPi, yAi, marker='o', markerfacecolor='green', markersize=6)
  #plt.semilogx(xPi,yAi)
  #plt.grid(True, which="both")
  #plt.show()



 ######## STEP A4 ##########
 ############ mu and sigma calculation ######################

  import matplotlib.pyplot as plt
  from scipy import optimize
  x=np.array(Qlist)
  y=np.array(lnAiList)
  #plt.xlabel('Qi')
  #plt.ylabel('lnAi')
  #plt.scatter(x,y)
  m_lna, sigma_lna = np.linalg.lstsq(np.vstack([np.ones(len(x)), x]).T, y, rcond=None)[0]
  mulist.append(m_lna)
  sigmalist.append(sigma_lna)
  #plt.show()
  #print('mu=', m_lna, 'sigma=', sigma_lna)


  import numpy

  mean = 0
  std = 1 
  k = 50000
  series = numpy.random.normal(mean, std, size=k)

  #plt.plot(series)
  #plt.title('White Gaussian Noise with Mean=0 and Var=1')
  #plt.xlabel('time (s)')
  #plt.show()


######################################################################################
######################################################################################
########### LPF ###########################
  from pandas import Series
  Ts=1
  beta=0.0002
  Xt=[0]
  timeser=[]
  X=[]
  for i in range(0,k):
    timeser.append(i)
    rho = math.exp(-1*beta*Ts)
    a1=rho*Xt[i]
    a2 = math.sqrt(1-rho**2)*series[i]
    Xtemp=a1+a2
    X.append(Xtemp)
    Xt.append(Xtemp)

#X=X[200000:k]  
#print(X)
  X=Series(X) 

  #X.plot()
  #plt.xlabel('time (s)')
  #plt.title('GWS filtered with low pass filter')
  #plt.show()


######################################################################################
######################################################################################
########### RAIN SERIES ###########################

  m=m_lna
#m=1.6073                       #TBE
  Yrain=[]
  for i in range(0,k):
    Yraintemp=math.exp(m+(sigma_lna*X[i]))
    Yrain.append(Yraintemp)
  Yrainall.append(Yrain)
#print(Yrain)

  import scipy.special
  sigma=sigma_lna 
#sigma=-0.4072                                                                   
  Arain=[]
  Aoffset=math.exp(m + sigma*(math.sqrt(2)*scipy.special.erfcinv(1-(2*Pannual/100))))
  for i in range(0,k):
    form=Yrain[i]-Aoffset
    Araintemp=max(form,0)
    Arain.append(Araintemp)
  Arainall.append(Arain)
#print(len(Arain))
#Arain=Arain[205000:k]
  A=Series(Arain)
  #plt.xlabel('Time(s)')
  #plt.ylabel('Arain (dB)')
#plt.xlim([4900,6000])
  #A.plot()
  #plt.title('Arain series generation')
  #plt.show()














  #print('\n')



print('theta elevation angle of all cities in degrees',thetadall)
print('Pannual of all cities list',Pannuallist)
print('Ai of all cities list:',Aiallcitieslist)
print('Mu for all cities',mulist)
print('sigma for all cities',sigmalist)

import matplotlib.pyplot as plt
MT1=MTall[0]
MT2=MTall[1]
MT3=MTall[2]
MT4=MTall[3]
#plt.rcParams['figure.figsize'] = [6,5]
plt.bar(Months, MT2, color='g', label='city2')
plt.bar(Months, MT1, color='r', label='city1')
plt.bar(Months, MT3, color='b', label='city3')
plt.bar(Months, MT4, color='y', label='city4')
plt.ylabel('Rainfall (mm)')
plt.xlabel('Month')
plt.rcParams['figure.figsize'] = [6,5]
plt.legend()
plt.show()


Pannual1=Pannuallist[0]
Pannual2=Pannuallist[1]
Pannual3=Pannuallist[2]
Pannual4=Pannuallist[3]

AttendBcity1=Aiallcitieslist[0]
AttendBcity2=Aiallcitieslist[1]
AttendBcity3=Aiallcitieslist[2]
AttendBcity4=Aiallcitieslist[3]


x1=Series(Piallcitieslist[0])
x2=Series(Piallcitieslist[1])
x3=Series(Piallcitieslist[2])
x4=Series(Piallcitieslist[3])

y1=Series(Aiallcitieslist[0])
y2=Series(Aiallcitieslist[1])
y3=Series(Aiallcitieslist[2])
y4=Series(Aiallcitieslist[3])
plt.plot(x1, y1, color='green', marker='*', markerfacecolor='c', markersize=6, label='city1')
plt.plot(x2, y2, color='red', marker='x', markerfacecolor='m', markersize=6, label='city2')
plt.plot(x3, y3, color='blue', marker='+', markerfacecolor='yellow', markersize=6, label='city3')
plt.plot(x4, y4, color='yellow', marker='o', markerfacecolor='green', markersize=6, label='city4')
plt.xscale('log')
plt.yticks(np.arange(0,30,2))
plt.grid(True, which="both")


#BERseries=BERseries[2300:2500]
plt.ylabel('Ai in dB')
plt.xlabel('Pi')
plt.title('Attenuation vs percent time exceeded')
#BERqpskseries.plot()
plt.legend()
plt.show()


Q1=np.array(Qall[0])
Q2=np.array(Qall[1])
Q3=np.array(Qall[2])
Q4=np.array(Qall[3])
lnA1=np.array(lnAiall[0])
lnA2=np.array(lnAiall[1])
lnA3=np.array(lnAiall[2])
lnA4=np.array(lnAiall[3])
plt.xlabel('Qi')
plt.ylabel('lnAi')
plt.title('ln Ai vs Q plot to calculate mu and sigma')
plt.plot(Q1, lnA1, color='green', marker='o', markerfacecolor='green', markersize=6, label='city1')
plt.plot(Q2, lnA2, color='red', marker='o', markerfacecolor='green', markersize=6, label='city2')
plt.plot(Q3, lnA3, color='blue', marker='o', markerfacecolor='green', markersize=6, label='city3')
plt.plot(Q4, lnA4, color='yellow', marker='o', markerfacecolor='green', markersize=6, label='city4')
plt.legend()
plt.show()






A1=Series(Arainall[0])
A2=Series(Arainall[1])
A3=Series(Arainall[2])
A4=Series(Arainall[3])
#plt.xlabel('Time(s)')
#plt.ylabel('Arain (dB)')
#plt.xlim([4900,6000])
#plt.plot(timeser, A1, color='green',label='city1')
#plt.plot(timeser, A2, color='red',label='city2')
#plt.plot(timeser, A3, color='blue',label='city3')
#plt.plot(timeser, A4, color='yellow',label='city4')
#plt.title('Arain series generation')
#plt.show()



import numpy

mean = 0
std = 1 
k = 50000
series = numpy.random.normal(mean, std, size=k)
plt.plot(series)
plt.title('White Gaussian Noise with Mean=0 and Var=1')
plt.xlabel('time (s)')
plt.show()

  #plt.plot(series)
  #plt.title('White Gaussian Noise with Mean=0 and Var=1')
  #plt.xlabel('time (s)')
  #plt.show()


######################################################################################
######################################################################################
########### LPF ###########################
for xx in range(0,4):
  Ts=1
  beta=0.0002
  Xt=[0]
  timeser=[]
  X=[]
  m=mulist[xx]
  sigma=sigmalist[xx] 
  for i in range(0,k):
    timeser.append(i)
    rho = math.exp(-1*beta*Ts)
    a1=rho*Xt[i]
    a2 = math.sqrt(1-rho**2)*series[i]
    Xtemp=a1+a2
    X.append(Xtemp)
    Xt.append(Xtemp)

#X=X[200000:k]  
#print(X)
  X=Series(X) 



                        
  Yrain=[]
  for i in range(0,k):
    Yraintemp=math.exp(m+((sigma)*X[i]))
    Yrain.append(Yraintemp)
  Yrainall.append(Yrain)
#print(Yrain)

  import scipy.special
  
#sigma=-0.4072                                                                   
  Arain=[]
  Aoffset=math.exp(m + sigma*(math.sqrt(2)*scipy.special.erfcinv(1-(2*(Pannuallist[xx])/100))))
  for i in range(0,k):
    Yrain=Yrainall[xx]
    form=Yrain[i]-Aoffset
    Araintemp=max(form,0)
    Arain.append(Araintemp)
  Arainall.append(Arain)
#print(len(Arain))
#Arain=Arain[205000:k]


X.plot()
plt.xlabel('time (s)')
plt.title('GWS filtered with low pass filter')
plt.show()


At1=Series(Arainall[0])
At2=Series(Arainall[1])
At3=Series(Arainall[2])
At4=Series(Arainall[3])
plt.xlabel('Time(s)')
plt.ylabel('Arain (dB)')
#plt.xlim([4900,6000])
plt.plot(timeser, At1, color='green',label='city1')
plt.plot(timeser, At2, color='red',label='city2')
plt.plot(timeser, At3, color='blue',label='city3')
plt.plot(timeser, At4, color='yellow',label='city4')
plt.title('Arain series generation')
plt.legend()
plt.show()
# Out:
# theta elevation angle of all cities in degrees [46.117070416526055, 49.767572564763846, 56.28419543442075, 56.385345465842946]
# Pannual of all cities list [0.6019057433958205, 0.8433598643389557, 0.7861079565288609, 0.9910729091709021]
# Ai of all cities list: [[21.813010310632468, 16.696986079695023, 14.071659016575312, 11.169218160968947, 7.940964303508164, 5.467615513805171, 4.329734612584357, 3.175402215583361], [18.68402929910034, 14.291220210522395, 12.038114893438888, 9.547727189458529, 6.777536000207691, 4.6531364943757785, 3.6740159127004786, 2.6780791121089758], [13.53934410124474, 10.581119891519236, 9.021111100787884, 7.256533176006655, 5.229922906335897, 3.6086538870824723, 2.8305498005312035, 2.0080339473163518], [16.175182152773232, 12.510398911015464, 10.604058846523676, 8.472198303255537, 6.062268819245941, 4.174367338749409, 3.2861412166732653, 2.3642373766409603]]
# Mu for all cities [1.0542209610869029, 0.8860950144979419, 0.627698701365821, 0.7762842794572884]
# ...

# %% [markdown]
# # ***Uplink***##

# %% [markdown]
# # ***ES to Satellite***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math                                                         
Fclossseries=[]
totloss=[]
pt=50                                                             #transmitted power in W
r=35786                                                           #distance in km from transmitting antenna
c=3*(10**8)                                                          ###  m/s
f=15                                                              ##GHz
fHz=f*(10**9)
Rearth=6371
#theta=math.radians(56.38)
slantrangeall=[]

for count in range(0,4):

# Slant range
  dist=Rearth+r
  cosfact=(math.cos(thetaall[count]))**2
  slantrange=(math.sqrt((dist**2)-((Rearth**2)*cosfact)))-(Rearth*math.sin(thetaall[count]))
  slantrangeall.append(slantrange)
  print('Slant range:',slantrange)


#transmitting antenna
nt=0.7                                                          #antenna efficiency factor
Dt=1                                                        #antenna diameter in m
Gt=nt*(math.pi*f*Dt)**2                                            #gain of transmitting antenna
Gtd=10*math.log10(Gt)                                            #gain of tramitting antenna in dB  #take f in GHz

#receiving antenna
nr=0.7
Dr=3                                                            #antenna diameter in m
Gr=nr*(math.pi*f*Dr)**2                                            #gain of receiving antenna
Grd=10*math.log10(Gr)                                            #gain of receiving antenna in dB   #take f in GHz 

###EIRP
ptdB=10*math.log10(pt)
eirp=ptdB+Gtd

###Free space loss

fsl=32.4+(20*(math.log10(slantrange)))+(20*(math.log10(f*(10**3)))) #free space loss
      

pl=0  #in dB                                                      #polarization mismatch loss
rfl=0                                                           #receiver feeder loss

## Total constant losses

aml=0
Fcloss=fsl+aml+rfl+pl
prdB=eirp+Grd-Fcloss                                              #received power
pr=10**(prdB/10)

print('Gain of receiver antenna:',Grd,'dB')
print('Gain of transmitter antenna:',Gtd,'dB')
print('Free space loss:',fsl,'dB')
print('Total constant loss:',Fcloss,'dB')
print('EIRP:',eirp,'dBW')
print('trans power in dB Pt=',ptdB)
print('Received power in dB Pr=',prdB)




print('\n')
###making a time series of constant loss

import matplotlib.pyplot as plt
from pandas import Series
Fclossseries=[]
totloss=[]
for i in range(0,k):
  Fclossseries.append(Fcloss)


totlossall=[]
### ADDING constant and variable loss
acount=0
for acount in range(0,4):
  Arain=Arainall[acount]
  totloss=[]
  for j in range(0,k):
    losstemp=Fclossseries[j]+Arain[j]                             #Arain derived from rain attenuation series
    totloss.append(losstemp)
  totlossall.append(totloss)

Tloss1=Series(totlossall[0])
Tloss2=Series(totlossall[1])
Tloss3=Series(totlossall[2])
Tloss4=Series(totlossall[3])



plt.xlabel('Time(s)')
plt.ylabel('Total losses (dB)')
plt.plot(timeser, Tloss1, color='green',label='city1')
plt.plot(timeser, Tloss2, color='red',label='city2')
plt.plot(timeser, Tloss3, color='blue',label='city3')
plt.plot(timeser, Tloss4, color='yellow',label='city4')
plt.title('Total propagation losses')
plt.legend()
plt.show()



CN0all=[]
cncount=0
for cncount in range(0,4):

  losses=Series(totlossall[cncount])
  T0=290
  Tant=290                                                  #antenna noise temp in k ##Satellite antenna
  Te1=150                                                   #LNA noise temperature in k
  Lcable=5                                                  #cable loss in dB
  L=10**(Lcable/10)
  Freceiver=3.01                                            #Receiver noise figure in dB  # source:satmaster
  F=10**(Freceiver/10)                                      #receiver noise factor
  LNAG=50                                                   #LNA gain in dB
  G1=10**(LNAG/10)
  Ts=Tant+Te1+((L-1)*T0/G1)+(L*(F-1)*T0/G1)
  TsdB=10*math.log10(Ts)
  CN0=eirp+Grd-TsdB-losses+228.6
  CN0all.append(CN0)
  #print('min C/N0',min(CN0))
  #print('max C/N0',max(CN0))
  GT=Grd-TsdB
  #print('G/T=',GT)
  #print('ts',TsdB)                                          #system noise temperature in dB
  #print('Ts',Ts)

CN01=CN0all[0]
CN02=CN0all[1]
CN03=CN0all[2]
CN04=CN0all[3]
plt.rcParams['figure.figsize'] = [6,5]
plt.xlabel('time(s)')
plt.ylabel('C/N0 dBHz')
plt.plot(timeser, CN01, color='green',label='city1')
plt.plot(timeser, CN02, color='red',label='city2')
plt.plot(timeser, CN03, color='blue',label='city3')
plt.plot(timeser, CN04, color='yellow',label='city4')
plt.title('Carrier to noise ratio of signal plot (normalized noise level (No))')
plt.legend()
plt.show()


print('\n')
BWN=100*1000000
Bn=10*math.log10(BWN)

ccount=0
CNall=[]
for ccount in range(0,4):
  CN=CN0all[ccount]-(Bn)
  CNall.append(CN)
  #print('C/N0',min(CN))
  GT=Grd-TsdB
  #print('min C/N',min(CN))
  #print('max C/N',max(CN))

CN1=CNall[0]
CN2=CNall[1]
CN3=CNall[2]
CN4=CNall[3]
plt.rcParams['figure.figsize'] = [6,5]
plt.xlabel('time(s)')
plt.ylabel('C/N dB')
plt.plot(timeser, CN1, color='green',label='city1')
plt.plot(timeser, CN2, color='red',label='city2')
plt.plot(timeser, CN3, color='blue',label='city3')
plt.plot(timeser, CN4, color='yellow',label='city4')

plt.title('CNR of signal plot')
plt.legend()
plt.show()
CN.plot()


CNtest=10**(CN0/10)
CNtest.plot()
plt.xlabel('time(s)')
plt.ylabel('C/N')
plt.show()
# Out:
# Slant range: 37333.09298096387
# Slant range: 37091.87119666839
# Slant range: 36709.00776368442
# Slant range: 36703.55989280317
# Gain of receiver antenna: 41.45822812953212 dB
# Gain of transmitter antenna: 31.91580303513887 dB
# Free space loss: 207.21598895488705 dB
# Total constant loss: 207.21598895488705 dB
# EIRP: 48.90550307849906 dBW
# trans power in dB Pt= 16.989700043360187
# Received power in dB Pr= -116.85225774685588

# %%
drate=100*(10**6)                           #data rate in bps
Rb=10*math.log10(drate)
EbN0=CN0-Rb
EbN0.plot()
plt.ylabel('Eb/N0 dB')
plt.xlabel('time s')
plt.show()

EbN01=CN01-Rb
EbN02=CN02-Rb
EbN03=CN03-Rb
EbN04=CN04-Rb
plt.rcParams['figure.figsize'] = [6,5]
plt.xlabel('time(s)')
plt.ylabel('Eb/N0 dB')
plt.plot(timeser, EbN01, color='green',label='city1')
plt.plot(timeser, EbN02, color='red',label='city2')
plt.plot(timeser, EbN03, color='blue',label='city3')
plt.plot(timeser, EbN04, color='yellow',label='city4')
plt.title('Eb/N0 plots for different cities')
plt.legend()
plt.show()






#BERqpsk=[]
#BERbpsk=[]
#for it in range(0,k):
 # ENtemp=10**(EbN01[it]/10)
  #EbNqpsktemp=math.sqrt(2*ENtemp)
  #BERqpsktemp=scipy.special.erfc(EbNqpsktemp)
  #BERqpsk.append(BERqpsktemp)

  #EbNbpsktemp=math.sqrt(ENtemp)
  #BERbpsktemp=0.5*scipy.special.erfc(EbNbpsktemp)
  #BERbpsk.append(BERbpsktemp)
  
time=[]
#plt.rcParams['figure.figsize'] = [6,5]
#BERqpskseries=Series(BERqpsk)
#BERbpskseries=Series(BERbpsk)
for i in range(0,k):
  time.append(i)
timeser=Series(time)
x=timeser
#a=BERqpskseries
#b=BERbpskseries
#plt.plot(x, a, color='r', label='BER qpsk')
#plt.plot(x, b, color='g', label='BER bpsk')
#BERqpskseries.plot()



#BERseries=BERseries[2300:2500]
#plt.ylabel('BER')
#plt.xlabel('time')
#plt.title('BER for QPSK')
#BERqpskseries.plot()
#plt.show()

# %%
#x=np.array(EbN0)
#a=np.array(BERqpskseries)
#b=np.array(BERbpskseries)
#c=np.array(BERseries1)

#plt.figure(figsize=(20,40))
#c=np.array(BERMpskseries)
#plt.xlabel('Eb/N0')
#plt.ylabel('BER')
#plt.plot(x, a, color='r', label='BER qpsk')
#plt.plot(x, b, color='g', label='BER bpsk')
#plt.yscale('log')  
#plt.xlabel("Eb/N0")
#plt.ylabel("BER")
#plt.title("BER for different modulations")
  
# Adding legend, which helps us recognize the curve according to it's color
#plt.legend()
#plt.show()
BERqpsk=[]
BERbpsk=[]
BERMpsk=[]
BERMqam=[]
for it in range(0,k):
  ENtemp=10**(EbN01[it]/10)
  EbNqpsktemp=math.sqrt(2*ENtemp)
  BERqpsktemp=scipy.special.erfc(EbNqpsktemp)
  BERqpsk.append(BERqpsktemp)

  EbNbpsktemp=math.sqrt(ENtemp)
  BERbpsktemp=0.5*scipy.special.erfc(EbNbpsktemp)
  BERbpsk.append(BERbpsktemp)


  ENtemp=10**(EbN01[it]/10)
  mtemp1=math.sqrt(6*ENtemp)
  mtemp2=math.sin((math.pi)/8)
  BERMpsktemp=(2/3)*(scipy.special.erfc(mtemp1*mtemp2))
  BERMpsk.append(BERMpsktemp)



  ENtemp=10**(EbN01[it]/10)
  mtemp1=math.sqrt((4/5)*ENtemp)
  BERMqamtemp=(3/4)*(scipy.special.erfc(mtemp1))
  BERMqam.append(BERMqamtemp)


BERqpskseries=Series(BERqpsk)
BERbpskseries=Series(BERbpsk)
BERMpskseries=Series(BERMpsk)
BERMqamseries=Series(BERMqam)




##############################################################################
#####   PLOTS    #######################



x=np.array(EbN01)
a=np.array(BERqpskseries)
b=np.array(BERbpskseries)
c=np.array(BERMpskseries)
d=np.array(BERMqamseries)

#plt.figure(figsize=(20,40))
#c=np.array(BERMpskseries)
plt.xlabel('Eb/N0')
plt.ylabel('BER')
plt.plot(x, a, color='r', label='BER qpsk')
plt.plot(x, b, color='g', label='BER bpsk')
plt.plot(x, c, color='m', label='BER M-psk (8)')
plt.plot(x, d, color='b', label='BER M-QAM (16)')
plt.yscale('log')  
# Naming the x-axis, y-axis and the whole graph
plt.xlabel("Eb/N0")
plt.ylabel("BER")
plt.title("BER for different modulations")
#plt.ylim((10**-4),1)
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
plt.show()

# %%
BERqpsk1=[]
BERbpsk1=[]
BERMpsk1=[]
BERMqam1=[]

BERqpsk2=[]
BERbpsk2=[]
BERMpsk2=[]
BERMqam2=[]

BERqpsk3=[]
BERbpsk3=[]
BERMpsk3=[]
BERMqam3=[]

BERqpsk4=[]
BERbpsk4=[]
BERMpsk4=[]
BERMqam4=[]
for it in range(0,k):

  ###QPSK
  ENtemp1=10**(EbN01[it]/10)
  BERqpsktemp1=scipy.special.erfc(math.sqrt(2*ENtemp1))
  BERqpsk1.append(BERqpsktemp1)

  ENtemp2=10**(EbN02[it]/10)
  BERqpsktemp2=scipy.special.erfc(math.sqrt(2*ENtemp2))
  BERqpsk2.append(BERqpsktemp2)

  ENtemp3=10**(EbN03[it]/10)
  BERqpsktemp3=scipy.special.erfc(math.sqrt(2*ENtemp3))
  BERqpsk3.append(BERqpsktemp3)

  ENtemp4=10**(EbN04[it]/10)
  BERqpsktemp4=scipy.special.erfc(math.sqrt(2*ENtemp4))
  BERqpsk4.append(BERqpsktemp4)

  #########BPSK
  BERbpsktemp1=0.5*scipy.special.erfc(math.sqrt(ENtemp1))
  BERbpsk1.append(BERbpsktemp1)

  BERbpsktemp2=0.5*scipy.special.erfc(math.sqrt(ENtemp2))
  BERbpsk2.append(BERbpsktemp2)

  BERbpsktemp3=0.5*scipy.special.erfc(math.sqrt(ENtemp3))
  BERbpsk3.append(BERbpsktemp3)

  BERbpsktemp4=0.5*scipy.special.erfc(math.sqrt(ENtemp4))
  BERbpsk4.append(BERbpsktemp4)

#### M-PSK
  mtemp1=math.sqrt(6*ENtemp1)
  BERMpsktemp1=(2/3)*(scipy.special.erfc(mtemp1*(math.sin((math.pi)/8))))
  BERMpsk1.append(BERMpsktemp1)

  mtemp2=math.sqrt(6*ENtemp1)
  BERMpsktemp2=(2/3)*(scipy.special.erfc(mtemp2*(math.sin((math.pi)/8))))
  BERMpsk2.append(BERMpsktemp2)

  mtemp3=math.sqrt(6*ENtemp3)
  BERMpsktemp3=(2/3)*(scipy.special.erfc(mtemp3*(math.sin((math.pi)/8))))
  BERMpsk3.append(BERMpsktemp3)

  mtemp4=math.sqrt(6*ENtemp4)
  BERMpsktemp4=(2/3)*(scipy.special.erfc(mtemp4*(math.sin((math.pi)/8))))
  BERMpsk4.append(BERMpsktemp4)

#### M-QAM
  BERMqamtemp1=(3/4)*(scipy.special.erfc(math.sqrt((4/5)*ENtemp1)))
  BERMqam1.append(BERMqamtemp1)

  BERMqamtemp2=(3/4)*(scipy.special.erfc(math.sqrt((4/5)*ENtemp2)))
  BERMqam2.append(BERMqamtemp2)

  BERMqamtemp3=(3/4)*(scipy.special.erfc(math.sqrt((4/5)*ENtemp3)))
  BERMqam3.append(BERMqamtemp3)

  BERMqamtemp4=(3/4)*(scipy.special.erfc(math.sqrt((4/5)*ENtemp4)))
  BERMqam4.append(BERMqamtemp4)






##SERIES

BERqpskseries1=Series(BERqpsk1)
BERbpskseries1=Series(BERbpsk1)
BERMpskseries1=Series(BERMpsk1)
BERMqamseries1=Series(BERMqam1)

BERqpskseries2=Series(BERqpsk2)
BERbpskseries2=Series(BERbpsk2)
BERMpskseries2=Series(BERMpsk2)
BERMqamseries2=Series(BERMqam2)

BERqpskseries3=Series(BERqpsk3)
BERbpskseries3=Series(BERbpsk3)
BERMpskseries3=Series(BERMpsk3)
BERMqamseries3=Series(BERMqam3)

BERqpskseries4=Series(BERqpsk4)
BERbpskseries4=Series(BERbpsk4)
BERMpskseries4=Series(BERMpsk4)
BERMqamseries4=Series(BERMqam4)





##############################################################################
#####   PLOTS    #######################



x1=np.array(EbN01)
a1=np.array(BERqpskseries1)
b1=np.array(BERbpskseries1)
c1=np.array(BERMpskseries1)
d1=np.array(BERMqamseries1)

x2=np.array(EbN02)
a2=np.array(BERqpskseries2)
b2=np.array(BERbpskseries2)
c2=np.array(BERMpskseries2)
d2=np.array(BERMqamseries2)

x3=np.array(EbN03)
a3=np.array(BERqpskseries3)
b3=np.array(BERbpskseries3)
c3=np.array(BERMpskseries3)
d3=np.array(BERMqamseries3)

x4=np.array(EbN04)
a4=np.array(BERqpskseries4)
b4=np.array(BERbpskseries4)
c4=np.array(BERMpskseries4)
d4=np.array(BERMqamseries4)

##### BER for QPSK

#plt.figure(figsize=(20,40))
plt.xlabel('Eb/N0')
plt.ylabel('BER')
plt.plot(x1, a1, color='r', label='city1')
plt.plot(x2, a2, color='g', label='city2')
plt.plot(x3, a3, color='m', label='city3')
plt.plot(x4, a4, color='b', label='city4')
plt.yscale('log')  
plt.xlabel("Eb/N0")
plt.ylabel("BER")
plt.title("BER for QPSK")
#plt.ylim((10**-4),1)
plt.legend()
plt.show()

###### BER for BPSK

plt.xlabel('Eb/N0')
plt.ylabel('BER')
plt.plot(x1, b1, color='r', label='city1')
plt.plot(x2, b2, color='g', label='city2')
plt.plot(x3, b3, color='m', label='city3')
plt.plot(x4, b4, color='b', label='city4')
plt.yscale('log')  
plt.xlabel("Eb/N0")
plt.ylabel("BER")
plt.title("BER for BPSK")
#plt.ylim((10**-4),1)
plt.legend()
plt.show()

# BER for M-PSK

plt.xlabel('Eb/N0')
plt.ylabel('BER')
plt.plot(x1, c1, color='r', label='city1')
plt.plot(x2, c2, color='g', label='city2')
plt.plot(x3, c3, color='m', label='city3')
plt.plot(x4, c4, color='b', label='city4')
plt.yscale('log')  
plt.xlabel("Eb/N0")
plt.ylabel("BER")
plt.title("BER for M-PSK")
#plt.ylim((10**-4),1)
plt.legend()
plt.show()


### BER for M-QAM

plt.xlabel('Eb/N0')
plt.ylabel('BER')
plt.plot(x1, d1, color='r', label='city1')
plt.plot(x2, d2, color='g', label='city2')
plt.plot(x3, d3, color='m', label='city3')
plt.plot(x4, d4, color='b', label='city4')
plt.yscale('log')  
plt.xlabel("Eb/N0")
plt.ylabel("BER")
plt.title("BER for QAM")
#plt.ylim((10**-4),1)
plt.legend()
plt.show()

# %% [markdown]
# ################################################################################

# %% [markdown]
# #Downlink

# %%
import math                                                         
Fclossseriesdl=[]
totlossdl=[]
ptdl=50                                                             #transmitted power in W
r=35786                                                             #distance in km from transmitting antenna
c=3*(10**9)                                                         ###  m/s
f=15                                                                ##GHz
fMHz=f*(10**3)
Rearth=6371
#theta=math.radians(56.38)

# Slant range
dist=Rearth+r
cosfact=(math.cos(theta))**2
slantrange=(math.sqrt((dist**2)-((Rearth**2)*cosfact)))-(Rearth*math.sin(theta))
print('Slant range:',slantrange)


#transmitting antenna
ntdl=0.7                                                          #antenna efficiency factor
Dtdl=3                                                         #antenna diameter in m
Gtdl=ntdl*(3.192*f*Dtdl)**2                                            #gain of transmitting antenna
Gtddl=10*math.log10(Gtdl)                                            #gain of tramitting antenna in dB  #take f in GHz

#receiving antenna
nrdl=0.7
Drdl=1                                                            #antenna diameter in m
Grdl=nrdl*(3.192*f*Drdl)**2                                            #gain of receiving antenna
Grddl=10*math.log10(Grdl)                                            #gain of receiving antenna in dB   #take f in GHz 

###EIRP
ptdBdl=10*math.log10(ptdl)
eirpdl=ptdBdl+Gtddl

###Free space loss

fsldl=32.4+(20*(math.log10(slantrange)))+(20*(math.log10(fMHz))) #free space loss  Dennis Roddy #f in MHz
#fsl=92.45+(20*(math.log10(slantrange)))+(20*(math.log10(f))) #free space loss  source:http://www.jocm.us/uploadfile/2019/0611/20190611102430249.pdf #f in GHz

#fsl=10*math.log10((4*math.pi*r*fHz/c)**2)


# AML     #antenna misalignment loss

#a=20                                                              #misalignment in degress
#fhz=f*10^3                                                        #f in Hz
#beamwidth=70*(c/(f*Dr))                                           #beamwidth (theta 3dB) in degrees  #satcomm wiley equation 5.4b
#aml=12*((a/beamwidth)**2)                                         #https://www.fxsolver.com/browse/formulas/Loss+due+to+Antenna+Misalignment


# other constant losses           

pl=0  #in dB                                                      #polarization mismatch loss
#aa=                                                              #fixed atmospheric absorption loss
rfl=0                                                           #receiver feeder loss

## Total constant losses

#Fcloss=fsl+aml+rfl+aa+pl                                         #total constant losses
aml=0
Fclossdl=fsldl+aml+rfl+pl
prdBdl=eirpdl+Grddl-Fclossdl                                      #received power
prdl=10**(prdBdl/10)

print('Gain of receiver antenna:',Grddl,'dB')
#print('Gain of receiver antenna:',Gr)
print('Gain of trans. antenna:',Gtddl,'dB')
#print('Gain of trans. antenna:',Gt)
print('Pt in dB:',ptdBdl,'dB')
print('Free space loss:',fsldl,'dB')
print('Total constant loss:',Fclossdl,'dB')
print('EIRP:',eirpdl,'dBW')
print('Received power in dB Pr=',prdBdl)


print('\n')
######################################################################################################################################
######################################################################################################################################
######################################################################################################################################


###making a time series of constant loss

import matplotlib.pyplot as plt
from pandas import Series
Fclossseriesdl=[]
totlossdl=[]
for i in range(0,k):
  Fclossseriesdl.append(Fclossdl)

### ADDING constant and variable loss

totlossalldl=[]
### ADDING constant and variable loss
acount=0
for acount in range(0,4):
  Arain=Arainall[acount]
  totlossdl=[]
  for j in range(0,k):
    losstempdl=Fclossseriesdl[j]+Arain[j]                             #Arain derived from rain attenuation series
    totlossdl.append(losstempdl)
  totlossalldl.append(totlossdl)

Tloss1dl=Series(totlossalldl[0])
Tloss2dl=Series(totlossalldl[1])
Tloss3dl=Series(totlossalldl[2])
Tloss4dl=Series(totlossalldl[3])



plt.xlabel('Time(s)')
plt.ylabel('Total losses (dB)')
plt.plot(timeser, Tloss1dl, color='green',label='city1')
plt.plot(timeser, Tloss2dl, color='red',label='city2')
plt.plot(timeser, Tloss3dl, color='blue',label='city3')
plt.plot(timeser, Tloss4dl, color='yellow',label='city4')
plt.title('Total propagation losses  for downlink ')
plt.legend()
plt.show()




print('\n')
print('\n')
######################################################################################################################################
######################################################################################################################################
######################################################################################################################################


############### CNR #########################3
############ C/N0 ##################3
CN0alldl=[]
cncount=0
for cncount in range(0,4):
  lossesdl=Series(totlossalldl[cncount])
  T0=290
  TantES=50.77                                             #antenna noise temp in k ## Earth station antenna
  Te1=150                                                   #LNA noise temperature in k
  Lcable=5                                                  #cable loss in dB
  L=10**(Lcable/10)
  Freceiver=3.01                                            #Receiver noise figure in dB  # source:satmaster
  F=10**(Freceiver/10)                                      #receiver noise factor
  LNAG=50                                                   #LNA gain in dB
  G1=10**(LNAG/10)
  Tsdl=TantES+Te1+((L-1)*T0/G1)+(L*(F-1)*T0/G1)
  TsdBdl=10*math.log10(Tsdl)
  CN0dl=[]
  CN0dl=eirpdl+Grddl-TsdBdl-lossesdl+228.6
  CN0alldl.append(CN0dl)
  #print('min C/N0',min(CN0dl))
  #print('max C/N0',max(CN0dl))
  GTdl=Grddl-TsdBdl
  #print('G/T=',GTdl)
  #print('ts',TsdBdl)                                          #system noise temperature in dB
  #print('Ts',Tsdl)

CN01dl=CN0alldl[0]
CN02dl=CN0alldl[1]
CN03dl=CN0alldl[2]
CN04dl=CN0alldl[3]
plt.rcParams['figure.figsize'] = [6,5]
plt.xlabel('time(s)')
plt.ylabel('C/N0 dBHz')
plt.plot(timeser, CN01dl, color='green',label='city1')
plt.plot(timeser, CN02dl, color='red',label='city2')
plt.plot(timeser, CN03dl, color='blue',label='city3')
plt.plot(timeser, CN04dl, color='yellow',label='city4')
plt.title('Carrier to noise ratio of signal plot for downlink (normalized noise level (No))')
plt.legend()
plt.show()






print('\n')
print('\n')
######################################################################################################################################
######################################################################################################################################
######################################################################################################################################


############### CNR #########################3
############ C/N0 ##################

import math
BWN=200*(10**6)
Bn=10*math.log10(BWN)


ccount=0
CNalldl=[]
for ccount in range(0,4):
  CNdl=CN0alldl[ccount]-(Bn)
  CNalldl.append(CNdl)
  #print('C/N0',min(CN))
  GTdl=Grddl-TsdBdl
  #print('min C/N',min(CN))
  #print('max C/N',max(CN))

CN1dl=CNalldl[0]
CN2dl=CNalldl[1]
CN3dl=CNalldl[2]
CN4dl=CNalldl[3]
plt.rcParams['figure.figsize'] = [6,5]
plt.xlabel('time(s)')
plt.ylabel('C/N dB')
plt.title('CNR of signal plot for downlink')
plt.plot(timeser, CN1dl, color='green',label='city1')
plt.plot(timeser, CN2dl, color='red',label='city2')
plt.plot(timeser, CN3dl, color='blue',label='city3')
plt.plot(timeser, CN4dl, color='yellow',label='city4')
plt.legend()
plt.show()




drate=100*(10**6)                           #data rate in bps
Rb=10*math.log10(drate)

EbN01dl=CN01dl-Rb
EbN02dl=CN02dl-Rb
EbN03dl=CN03dl-Rb
EbN04dl=CN04dl-Rb
plt.rcParams['figure.figsize'] = [6,5]
plt.xlabel('time(s)')
plt.ylabel('Eb/N0 dB')
plt.plot(timeser, EbN01dl, color='green',label='city1')
plt.plot(timeser, EbN02dl, color='red',label='city2')
plt.plot(timeser, EbN03dl, color='blue',label='city3')
plt.plot(timeser, EbN04dl, color='yellow',label='city4')
plt.title('Eb/N0 plots for different cities')
plt.legend()
plt.show()







BERqpskdl=[]
BERbpskdl=[]
for l in range(0,k):
  ENtempdl=10**((EbN04dl[l])/10)
  EbNqpsktempdl=math.sqrt(2*ENtempdl)
  BERqpsktempdl=scipy.special.erfc(EbNqpsktempdl)
  BERqpskdl.append(BERqpsktempdl)

  EbNbpsktempdl=math.sqrt(2*ENtempdl)
  BERbpsktempdl=0.5*scipy.special.erfc(EbNbpsktempdl)
  BERbpskdl.append(BERbpsktempdl)
  
time=[]
BERqpskseriesdl=Series(BERqpskdl)
BERbpskseriesdl=Series(BERbpskdl)
for i in range(0,k):
  time.append(i)
timeser=Series(time)
x=timeser
a=BERqpskseriesdl
b=BERbpskseriesdl
plt.plot(x, a, color='r', label='BER qpsk')
plt.plot(x, b, color='g', label='BER bpsk')


#BERseries=BERseries[2300:2500]
plt.ylabel('BER')
plt.xlabel('time')
plt.title('BER for QPSK')
#BERqpskseries.plot()
plt.legend()
plt.show()
# Out:
# Slant range: 36703.55989280317
# Gain of receiver antenna: 32.05406323483003 dB
# Gain of trans. antenna: 41.596488329223284 dB
# Pt in dB: 16.989700043360187 dB
# Free space loss: 207.21598895488705 dB
# Total constant loss: 207.21598895488705 dB
# EIRP: 58.58618837258347 dBW
# Received power in dB Pr= -116.57573734747355

# %%
BERqpskdl=[]
BERbpskdl=[]
BERMpskdl=[]
BERMqamdl=[]
for it in range(0,k):
  ENtempdl=10**(EbN04dl[it]/10)
  EbNqpsktempdl=math.sqrt(2*ENtempdl)
  BERqpsktempdl=0.5*scipy.special.erfc(EbNqpsktempdl)
  BERqpskdl.append(BERqpsktempdl)

  EbNbpsktempdl=math.sqrt(ENtempdl)
  BERbpsktempdl=0.5*scipy.special.erfc(EbNbpsktempdl)
  BERbpskdl.append(BERbpsktempdl)

  mtemp1dl=math.sqrt(6*ENtempdl)
  mtemp2dl=math.sin((math.pi)/8)
  BERMpsktempdl=(2/3)*(scipy.special.erfc(mtemp1dl*mtemp2dl))
  BERMpskdl.append(BERMpsktempdl)

  mtemp1dl=math.sqrt((4/5)*ENtempdl)
  BERMqamtempdl=(3/4)*(scipy.special.erfc(mtemp1dl))
  BERMqamdl.append(BERMqamtempdl)


BERqpskseriesdl=Series(BERqpskdl)
BERbpskseriesdl=Series(BERbpskdl)
BERMpskseriesdl=Series(BERMpskdl)
BERMqamseriesdl=Series(BERMqamdl)

##############################################################################
#####   PLOTS    #######################



x=np.array(EbN04dl)
a=np.array(BERqpskseriesdl)
b=np.array(BERbpskseriesdl)
c=np.array(BERMpskseriesdl)
d=np.array(BERMqamseriesdl)

#plt.figure(figsize=(20,40))
#c=np.array(BERMpskseries)
plt.xlabel('Eb/N0')
plt.ylabel('BER')
plt.plot(x, a, color='r', label='BER qpsk')
plt.plot(x, b, color='g', label='BER bpsk')
plt.plot(x, c, color='m', label='BER M-psk (8)')
plt.plot(x, d, color='b', label='BER M-QAM (16)')
plt.yscale('log')  
# Naming the x-axis, y-axis and the whole graph
plt.xlabel("Eb/N0")
plt.ylabel("BER")
plt.title("BER (DOWNLINK) for different modulations")
plt.ylim((10**-5),1)
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
plt.show()

# %%
ebn0t=EbN0dl+EbN0
ebn0t.plot()
plt.show()
plt.title('Eb/N0')

BERtot=[]
for it in range(0,k):
  #ENtemp=10**((EbN0[l])/10)
  ENtemp=10**(ebn0t[it]/10)
  EbNtottemp=math.sqrt(ENtemp)
  BERtottemp=0.5*scipy.special.erfc(EbNtottemp)
  BERtot.append(BERtottemp)




BERtotser=Series(BERtot)
BERtotser.plot()
plt.ylabel('BER')
plt.xlabel('time')
plt.title('BER for QPSK')
plt.show()
#a=BERtotser
x=np.array(ebn0t)
a=np.array(BERtotser)
#b=np.array(BERbpskseriesdl)
#c=np.array(BERMpskseries)
plt.xlabel('Eb/N0')
plt.ylabel('BER')
plt.plot(x, a, color='r', label='BER qpsk')
#plt.plot(x, b, color='g', label='BER bpsk')
#plt.plot(x, c, color='b', label='BER Mpsk')
plt.yscale('log') 
# Naming the x-axis, y-axis and the whole graph
plt.xlabel("Eb/N0")
plt.ylabel("BER")
plt.title("BER for different modulations")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
plt.show()
